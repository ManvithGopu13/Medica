# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("medical_dataset.csv")

# %%
df.head()
# Out:
#                                    condition  \
# 0  Abdominal aortic aneurysm (AAA) screening
# 1                  Abdominal aortic aneurysm
# 2                  Abdominal aortic aneurysm
# 3  Abdominal aortic aneurysm (AAA) screening
# 4                                   Abortion
#
#                                             symptoms
# 0                                                NaN
# 1  tummy or back pain, a pulsing feeling in your ...
# 2  tummy or back pain, a pulsing feeling in your ...
# 3                                                NaN
# 4                                                NaN

# %%
# Step 1: Clean the data by removing rows with empty symptoms or overview columns
df = df[df['symptoms'].notna()]  # Remove rows where symptoms are NaN
df = df[df['symptoms'].str.strip().str.lower() != 'overview']  # Remove rows that have 'overview' in symptoms column
df = df[df['symptoms'].str.strip() != '']  # Remove rows with empty symptoms
df = df[df['symptoms'].str.strip() != '-']  # Remove rows with empty symptoms

# Clean the 'condition' column by removing "Overview\n-" and any unwanted text
df['condition'] = df['condition'].str.replace(r'Overview\n-\n', '', regex=True)

df = df.drop_duplicates()

# %%
df.head(20)
# Out:
#                                      condition  \
# 1                    Abdominal aortic aneurysm
# 6                                    Achalasia
# 9                                         Acne
# 10    Acoustic neuroma (vestibular schwannoma)
# 11                                  Acromegaly
# 15                         Acute cholecystitis
# 16                         Acute kidney injury
# 18                     Acute myeloid leukaemia
# 19                          Acute pancreatitis
# 20  Acute respiratory distress syndrome (ARDS)
# 21                           Addison's disease
# 23                                 Adenomyosis
# 30               Alcohol-related liver disease
# 35                           Altitude sickness
# 41                                 Amyloidosis
# 44    Vitamin B12 or folate deficiency anaemia
# 47                                Anal fistula
# 54                                      Angina
# 60                      Ankylosing spondylitis
# 72               Anxiety disorders in children
#
#                                              symptoms
# 1   tummy or back pain, a pulsing feeling in your ...
# 6   bringing back up undigested food, choking and ...
# 9   face – this affects almost everyone with acne,...
# 10  hearing loss that usually only affects 1 ear, ...
# 11  swollen hands and feet – you may notice a chan...
# 15  a high temperature, feeling sick, being sick, ...
# 16  feeling sick or being sick, diarrhoea, dehydra...
# 18  looking pale or "washed out", feeling tired or...
# 19  suddenly getting severe pain in the centre of ...
# 20    shortness of breath, taking short, fast breaths
# 21  lack of energy or motivation (fatigue), muscle...
# 23  painful periods, heavy bleeding during your pe...
# 30  feeling sick, weight loss, loss of appetite, y...
# 35  a headache, loss of appetite, feeling or being...
# 41  feeling very tired or weak, losing weight with...
# 44  extreme tiredness, a lack of energy, pins and ...
# 47  skin irritation around the anus, a constant, t...
# 54  feels tight, dull or heavy – it may spread to ...
# 60  back pain and stiffness, pain and swelling in ...
# 72  finding it hard to concentrate, not sleeping, ...

# %%
# Step 5: Save the updated dataset to a new CSV
df.to_csv("updated_medical_dataset.csv", index=False)

# %% [markdown]
# ## MODEL BUILDING

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
# Step 1: Load the dataset
df = pd.read_csv('updated_medical_dataset.csv')

# %%
# Step 2: Preprocess the symptoms and convert them to a binary feature vector

# Create a list of all unique symptoms
all_symptoms = set()
for symptoms in df['symptoms']:
    all_symptoms.update(symptoms.lower().split(','))  # Split symptoms by comma and convert to lower case
all_symptoms = list(all_symptoms)  # Convert to list for later use

# %%
# Step 3: Convert symptoms to binary vector
def symptoms_to_vector(symptoms, all_symptoms):
    symptom_vector = [0] * len(all_symptoms)  # Initialize a vector with 0's
    symptom_list = [s.strip() for s in symptoms.lower().split(',')]  # Clean symptoms and split by commas
    for symptom in symptom_list:
        if symptom in all_symptoms:
            symptom_vector[all_symptoms.index(symptom)] = 1  # Mark 1 if the symptom is present
    return symptom_vector

# %%
# Step 4: Prepare the feature matrix and target variable
X = [symptoms_to_vector(symptoms, all_symptoms) for symptoms in df['symptoms']]
y = df['condition']  # The target variable is the disease condition

# %%
# Step 5: Encode the target variable (condition)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Step 6: Train the model on all data (using the entire dataset)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X, y_encoded)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Step 7: Evaluate the model on the training data (as all data is being used for training)
y_pred = model.predict(X)
accuracy = accuracy_score(y_encoded, y_pred)
print(f"Training Accuracy: {accuracy * 100:.2f}%")
# Out:
# Training Accuracy: 96.61%

# %%
# Print classification report
print("\nClassification Report (Training Data):")
print(classification_report(y_encoded, y_pred, target_names=label_encoder.classes_))
# Out:
# Classification Report (Training Data):
#                                                                 precision    recall  f1-score   support
#
#                                      Abdominal aortic aneurysm       1.00      1.00      1.00         1
#                                                      Achalasia       1.00      1.00      1.00         1
#                                                           Acne       1.00      1.00      1.00         1
#                       Acoustic neuroma (vestibular schwannoma)       1.00      1.00      1.00         1
#                                                     Acromegaly       1.00      1.00      1.00         1
#                                            Acute cholecystitis       1.00      1.00      1.00         1
#                                            Acute kidney injury       1.00      1.00      1.00         1
#                                        Acute myeloid leukaemia       1.00      1.00      1.00         1
#                                             Acute pancreatitis       1.00      1.00      1.00         1
#                     Acute respiratory distress syndrome (ARDS)       0.00      0.00      0.00         1
#                                              Addison's disease       1.00      1.00      1.00         1
#                                                    Adenomyosis       1.00      1.00      1.00         1
#                                  Alcohol-related liver disease       1.00      1.00      1.00         1
#                                              Altitude sickness       1.00      1.00      1.00         1
#                                                    Amyloidosis       1.00      1.00      1.00         1
#                                                   Anal fistula       1.00      1.00      1.00         1
#                                                         Angina       1.00      1.00      1.00         1
#                                         Ankylosing spondylitis       1.00      1.00      1.00         1
#                                  Anxiety disorders in children       1.00      1.00      1.00         1
#                                                        Aphasia       1.00      1.00      1.00         1
#                                                   Appendicitis       1.00      1.00      1.00         1
#                                                      Arthritis       1.00      1.00      1.00         1
#                                                     Asbestosis       0.33      1.00      0.50         1
#                                                  Aspergillosis       1.00      1.00      1.00         1
#                                                         Asthma       1.00      1.00      1.00         1
#                                            Atrial fibrillation       1.00      1.00      1.00         1
#                                               Behçet's disease       1.00      1.00      1.00         1
#                                                   Bell's palsy       1.00      1.00      1.00         1
#                            Benign brain tumour (non-cancerous)       1.00      1.00      1.00         1
#                                    Benign prostate enlargement       1.00      1.00      1.00         1
#                                               Bipolar disorder       1.00      1.00      1.00         1
#                                                       Bird flu       1.00      1.00      1.00         1
#                  Bladder pain syndrome (interstitial cystitis)       1.00      1.00      1.00         1
#                                                       Bloating       1.00      1.00      1.00         1
#                                 Body dysmorphic disorder (BDD)       1.00      1.00      1.00         1
#                                                      Bone cyst       1.00      1.00      1.00         1
#                                                       Botulism       1.00      1.00      1.00         1
#                                                   Bowel polyps       1.00      1.00      1.00         1
#                                                Bowen's disease       1.00      1.00      1.00         1
#                                                  Brain abscess       1.00      1.00      1.00         1
#                                                  Brain tumours       1.00      1.00      1.00         1
#                                                     Bronchitis       1.00      1.00      1.00         1
#                                                    Brucellosis       1.00      1.00      1.00         1
#                                               Brugada syndrome       1.00      1.00      1.00         1
#                                                        Bulimia       1.00      1.00      1.00         1
#                                                      Cavernoma       1.00      1.00      1.00         1
#                                                 Cerebral palsy       1.00      1.00      1.00         1
#                                            Chiari malformation       1.00      1.00      1.00         1
#                                                        Cholera       1.00      1.00      1.00         1
#                                                  Cholesteatoma       1.00      1.00      1.00         1
#                                         Chronic kidney disease       1.00      1.00      1.00         1
#                   Chronic obstructive pulmonary disease (COPD)       0.00      0.00      0.00         1
#                                                      Cirrhosis       1.00      1.00      1.00         1
#                                                 Claustrophobia       1.00      1.00      1.00         1
#                                                Coeliac disease       0.00      0.00      0.00         1
#                                         Coronary heart disease       1.00      1.00      1.00         1
#                                      Creutzfeldt-Jakob disease       1.00      1.00      1.00         1
#                                                Crohn's disease       0.50      1.00      0.67         1
#                                             Cushing's syndrome       1.00      1.00      1.00         1
#                                                     Cyclospora       1.00      1.00      1.00         1
#                                                Cystic fibrosis       1.00      1.00      1.00         1
#                                          Cytomegalovirus (CMV)       0.00      0.00      0.00         1
#                                     DVT (deep vein thrombosis)       1.00      1.00      1.00         1
#                                      Dementia with Lewy bodies       1.00      1.00      1.00         1
#                                                         Dengue       1.00      1.00      1.00         1
#                             DiGeorge syndrome (22q11 deletion)       1.00      1.00      1.00         1
#                                           Diabetic retinopathy       1.00      1.00      1.00         1
#                                                     Diphtheria       1.00      1.00      1.00         1
#                                                 Discoid eczema       1.00      1.00      1.00         1
#                                         Dissociative disorders       1.00      1.00      1.00         1
#                        Diverticular disease and diverticulitis       1.00      1.00      1.00         1
#     Dyspraxia (developmental co-ordination disorder) in adults       1.00      1.00      1.00         1
#                                                Earwax build-up       1.00      1.00      1.00         1
#                                            Ebola virus disease       1.00      1.00      1.00         1
#                                              Ectopic pregnancy       1.00      1.00      1.00         1
#                                        Ehlers-Danlos syndromes       1.00      1.00      1.00         1
#                                                   Encephalitis       1.00      1.00      1.00         1
#                                                   Endocarditis       1.00      1.00      1.00         1
#                                                  Endometriosis       1.00      1.00      1.00         1
#                                          Epidermolysis bullosa       1.00      1.00      1.00         1
#                                                   Epiglottitis       1.00      1.00      1.00         1
#                                                       Epilepsy       1.00      1.00      1.00         1
#                                                 Erythrocytosis       1.00      1.00      1.00         1
#                                                     Eye cancer       1.00      1.00      1.00         1
#                                                       Fainting       1.00      1.00      1.00         1
#                                                   Fibromyalgia       1.00      1.00      1.00         1
#                                        Frontotemporal dementia       1.00      1.00      1.00         1
#                                                     Gallstones       1.00      1.00      1.00         1
#                             Generalised anxiety disorder (GAD)       1.00      1.00      1.00         1
#                                           Gestational diabetes       1.00      1.00      1.00         1
#                                                     Giardiasis       1.00      1.00      1.00         1
#                                                       Glaucoma       1.00      1.00      1.00         1
#                                             Glomerulonephritis       1.00      1.00      1.00         1
#                         Granulomatosis with polyangiitis (GPA)       1.00      1.00      1.00         1
#                                        Guillain-Barré syndrome       1.00      1.00      1.00         1
#                                               Haemochromatosis       1.00      1.00      1.00         1
#                                                    Haemophilia       1.00      1.00      1.00         1
#                            Haemophilus influenzae type b (Hib)       1.00      1.00      1.00         1
#                                                   Heart attack       1.00      1.00      1.00         1
#                                                    Heart block       1.00      1.00      1.00         1
#                                                  Heart failure       1.00      1.00      1.00         1
#                             Heart rhythm problems (arrhythmia)       1.00      1.00      1.00         1
#                                                      Hepatitis       1.00      1.00      1.00         1
#                                                    Hepatitis C       0.50      1.00      0.67         1
#                   Hereditary haemorrhagic telangiectasia (HHT)       1.00      1.00      1.00         1
#                                  Hereditary spastic paraplegia       1.00      1.00      1.00         1
#                                  Hidradenitis suppurativa (HS)       1.00      1.00      1.00         1
#                                            High blood pressure       1.00      1.00      1.00         1
#                              High blood sugar (hyperglycaemia)       1.00      1.00      1.00         1
#                                         Hirschsprung's disease       1.00      1.00      1.00         1
#                                           Huntington's disease       1.00      1.00      1.00         1
#                                                  Hydrocephalus       1.00      1.00      1.00         1
#                                            Hyperparathyroidism       1.00      1.00      1.00         1
#                                             Hypoparathyroidism       1.00      1.00      1.00         1
#                                  Idiopathic pulmonary fibrosis       1.00      1.00      1.00         1
#                                     Inflammatory bowel disease       1.00      1.00      1.00         1
#                                      Intracranial hypertension       1.00      1.00      1.00         1
#                                           Isovaleric acidaemia       1.00      1.00      1.00         1
#                                          Japanese encephalitis       1.00      1.00      1.00         1
#                                                        Jet lag       1.00      1.00      1.00         1
#                                   Joint hypermobility syndrome       1.00      1.00      1.00         1
#                                               Kidney infection       1.00      1.00      1.00         1
#                                                  Kidney stones       1.00      1.00      1.00         1
#                                           Klinefelter syndrome       1.00      1.00      1.00         1
#                              Lambert-Eaton myasthenic syndrome       1.00      1.00      1.00         1
#                                      Laryngeal (larynx) cancer       1.00      1.00      1.00         1
#                                 Leptospirosis (Weil's disease)       1.00      1.00      1.00         1
#                                                    Listeriosis       1.00      1.00      1.00         1
#                                                  Liver disease       1.00      1.00      1.00         1
#                                               Long QT syndrome       1.00      1.00      1.00         1
#                               Low blood pressure (hypotension)       1.00      1.00      1.00         1
#                                                   Lyme disease       1.00      1.00      1.00         1
#                                                    Lymphoedema       1.00      1.00      1.00         1
#                                                          MCADD       1.00      1.00      1.00         1
#                                                           MRSA       1.00      1.00      1.00         1
#                                                        Malaria       0.00      0.00      0.00         1
#                          Malignant brain tumour (brain cancer)       1.00      1.00      1.00         1
#                                                   Mastocytosis       1.00      1.00      1.00         1
#                                                     Meningitis       1.00      1.00      1.00         1
#                                                   Mesothelioma       1.00      1.00      1.00         1
#                        Middle East respiratory syndrome (MERS)       0.00      0.00      0.00         1
#                                          Motor neurone disease       1.00      1.00      1.00         1
#                                                           Mpox       1.00      1.00      1.00         1
#                                                      Mucositis       1.00      1.00      1.00         1
#                                               Multiple myeloma       1.00      1.00      1.00         1
#                                             Multiple sclerosis       1.00      1.00      1.00         1
#                                        Multiple system atrophy       1.00      1.00      1.00         1
# Myalgic encephalomyelitis or chronic fatigue syndrome (ME/CFS)       1.00      1.00      1.00         1
#                                              Myasthenia gravis       1.00      1.00      1.00         1
#                      Myelodysplastic syndrome (myelodysplasia)       1.00      1.00      1.00         1
#                                          Nail patella syndrome       1.00      1.00      1.00         1
#                                         Nasal and sinus cancer       1.00      1.00      1.00         1
#                                          Nasopharyngeal cancer       1.00      1.00      1.00         1
#                                       Neurofibromatosis type 1       1.00      1.00      1.00         1
#                                       Neurofibromatosis type 2       1.00      1.00      1.00         1
#                                     Neuromyelitis optica (NMO)       1.00      1.00      1.00         1
#                          Newborn respiratory distress syndrome       1.00      1.00      1.00         1
#                      Non-alcoholic fatty liver disease (NAFLD)       1.00      1.00      1.00         1
#                                       Norovirus (vomiting bug)       1.00      1.00      1.00         1
#                                                 Osteoarthritis       1.00      1.00      1.00         1
#                                                  Osteomyelitis       1.00      1.00      1.00         1
#                                         Osteophyte (bone spur)       1.00      1.00      1.00         1
#                                                   Ovarian cyst       1.00      1.00      1.00         1
#                           Overactive thyroid (hyperthyroidism)       1.00      1.00      1.00         1
#                                    PMS (premenstrual syndrome)       1.00      1.00      1.00         1
#                                        Paget's disease of bone       1.00      1.00      1.00         1
#                                                 Panic disorder       1.00      1.00      1.00         1
#                                                      Paralysis       1.00      1.00      1.00         1
#                                            Parkinson's disease       1.00      1.00      1.00         1
#                                               Patau's syndrome       1.00      1.00      1.00         1
#                                    Pelvic inflammatory disease       1.00      1.00      1.00         1
#                                          Pelvic organ prolapse       1.00      1.00      1.00         1
#                                                    Pelvic pain       1.00      1.00      1.00         1
#                              Peripheral arterial disease (PAD)       1.00      1.00      1.00         1
#                                          Peripheral neuropathy       1.00      1.00      1.00         1
#                                              Phaeochromocytoma       1.00      1.00      1.00         1
#                                                Phenylketonuria       1.00      1.00      1.00         1
#                                                      Pneumonia       1.00      1.00      1.00         1
#                                                          Polio       1.00      1.00      1.00         1
#                                      Polycystic ovary syndrome       1.00      1.00      1.00         1
#                       Polyhydramnios (too much amniotic fluid)       1.00      1.00      1.00         1
#                                     Polymorphic light eruption       1.00      1.00      1.00         1
#                                         Polymyalgia rheumatica       1.00      1.00      1.00         1
#                                        Post-herpetic neuralgia       1.00      1.00      1.00         1
#                                            Post-polio syndrome       1.00      1.00      1.00         1
#                                           Postpartum psychosis       1.00      1.00      1.00         1
#                                          Prader-Willi syndrome       1.00      1.00      1.00         1
#                                                  Pre-eclampsia       1.00      1.00      1.00         1
#        Primary biliary cholangitis (primary biliary cirrhosis)       1.00      1.00      1.00         1
#                                                Prostate cancer       1.00      1.00      1.00         1
#                                           Psychotic depression       1.00      1.00      1.00         1
#                                         Pulmonary hypertension       1.00      1.00      1.00         1
#                                                        Q fever       0.50      1.00      0.67         1
#                                                         Rabies       1.00      1.00      1.00         1
#                                             Reactive arthritis       1.00      1.00      1.00         1
#                              Respiratory syncytial virus (RSV)       1.00      1.00      1.00         1
#                                                Rheumatic fever       0.00      0.00      0.00         1
#                                                    Sarcoidosis       1.00      1.00      1.00         1
#                                    Schistosomiasis (bilharzia)       1.00      1.00      1.00         1
#                                                      Scoliosis       1.00      1.00      1.00         1
#                                                         Scurvy       1.00      1.00      1.00         1
#                                            Sickle cell disease       1.00      1.00      1.00         1
#                                             Sjögren's syndrome       1.00      1.00      1.00         1
#                                 Social anxiety (social phobia)       1.00      1.00      1.00         1
#                                                   Spina bifida       1.00      1.00      1.00         1
#                                  Spinal muscular atrophy (SMA)       1.00      1.00      1.00         1
#                                       Stevens-Johnson syndrome       1.00      1.00      1.00         1
#                                                        Strep A       0.00      0.00      0.00         1
#                                       Subarachnoid haemorrhage       1.00      1.00      1.00         1
#                             Supraventricular tachycardia (SVT)       1.00      1.00      1.00         1
#                                              Tay-Sachs disease       1.00      1.00      1.00         1
#                                       Teeth grinding (bruxism)       1.00      1.00      1.00         1
#                                             Temporal arteritis       1.00      1.00      1.00         1
#                                                     Tendonitis       1.00      1.00      1.00         1
#                                                        Tetanus       1.00      1.00      1.00         1
#                                                   Thalassaemia       1.00      1.00      1.00         1
#                                                  Thrombophilia       1.00      1.00      1.00         1
#                                  Tick-borne encephalitis (TBE)       1.00      1.00      1.00         1
#                                            Tourette's syndrome       1.00      1.00      1.00         1
#                                                   Toxocariasis       0.25      1.00      0.40         1
#                               Transient ischaemic attack (TIA)       1.00      1.00      1.00         1
#                                                 Trichomoniasis       1.00      1.00      1.00         1
#                       Trichotillomania (hair pulling disorder)       1.00      1.00      1.00         1
#                      Trimethylaminuria ('fish odour syndrome')       1.00      1.00      1.00         1
#                                                  Typhoid fever       1.00      1.00      1.00         1
#                                                         Typhus       1.00      1.00      1.00         1
#                                             Ulcerative colitis       1.00      1.00      1.00         1
#                                                Vaginal dryness       1.00      1.00      1.00         1
#                                                Varicose eczema       1.00      1.00      1.00         1
#                                              Vascular dementia       1.00      1.00      1.00         1
#                       Vitamin B12 or folate deficiency anaemia       1.00      1.00      1.00         1
#                                                       Vitiligo       1.00      1.00      1.00         1
#                                                  Vulval cancer       1.00      1.00      1.00         1
#                                 Wolff-Parkinson-White syndrome       1.00      1.00      1.00         1
#                                                   Yellow fever       1.00      1.00      1.00         1
#                                                     Zika virus       1.00      1.00      1.00         1
#
#                                                       accuracy                           0.97       236
#                                                      macro avg       0.95      0.97      0.96       236
#                                                   weighted avg       0.95      0.97      0.96       236
# c:\Users\saish\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\saish\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\saish\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Step 8: Function to predict for new symptoms
def predict_disease(symptoms_input):
    # Convert the symptoms input into the same format as the training data (binary vector)
    symptom_vector = symptoms_to_vector(symptoms_input, all_symptoms)

    # Make prediction
    prediction = model.predict([symptom_vector])
    predicted_condition = label_encoder.inverse_transform(prediction)[0]
    
    # Get the probabilities for each condition
    probabilities = model.predict_proba([symptom_vector])[0]
    
    # Print the predicted condition and probabilities
    print(f"Predicted Condition: {predicted_condition}")
    
    # Print only conditions with probability > 50%
    for condition, probability in zip(label_encoder.classes_, probabilities):
        if probability > 0.10:  # Only print if probability is greater than 50%
            print(f"{condition}: {probability * 100:.2f}%")

# %%
# Step 9: Test the model with a random symptom input
random_symptoms = "fever, headache, stomach pain"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Typhoid fever
# Endocarditis: 12.00%
# Hydrocephalus: 20.00%
# Sarcoidosis: 19.00%
# Typhoid fever: 27.00%

# %%
random_symptoms = "needing to pee suddenly or more often than usual, pain or a burning sensation when peeing, smelly or cloudy pee, blood in your pee"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Kidney infection
# Kidney infection: 67.00%

# %%
random_symptoms = "pain in the side of your tummy (abdomen), severe pain that comes and goes, feeling sick or vomiting"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Kidney stones
# Kidney stones: 65.00%

# %%
random_symptoms = "a high temperature, sweats and chills, headaches and feeling confused, feeling very tired and sleepy (especially in children), feeling and being sick, tummy pain and diarrhoea, loss of appetite, muscle pains, yellow skin or whites of the eyes, a sore throat, cough and difficulty breathing"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Toxocariasis
# Malaria: 25.86%
# Middle East respiratory syndrome (MERS): 20.58%
# Rheumatic fever: 24.19%
# Toxocariasis: 28.37%

# %%
random_symptoms = "you cannot move some or all of your face or body, your face or body is weak or floppy, your face or body is numb, painful or tingles all the time, your face or body is stiff with muscle spasms and twitches"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Paralysis
# Paralysis: 63.00%

# %%
random_symptoms = "a high temperature, extreme tiredness (fatigue), headaches, being sick (vomiting), a stiff neck, muscle pain"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Polio
# Polio: 65.00%

# %%
random_symptoms = "feeling very tired and weak all the time, feeling irritable and sad all the time, joint, muscle or leg pain, swollen, bleeding gums (sometimes teeth can fall out), developing red or blue spots on the skin, usually on the legs and feet, although this may be less noticeable on brown or black skin, skin that bruises easily"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Scurvy
# Liver disease: 13.00%
# Scurvy: 58.00%

# %%
random_symptoms = "pain in a tendon that gets worse when you move, difficulty moving the joint, feeling a grating or crackling sensation when you move the tendon, swelling, sometimes with heat or redness"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Tendonitis
# Osteoarthritis: 19.00%
# Tendonitis: 67.00%

# %%
random_symptoms = "a persistent high temperature that gradually increases each day, headache, general aches and pains, extreme tiredness (fatigue), cough, constipation"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Typhoid fever
# Typhoid fever: 71.00%

# %%
random_symptoms = "a high temperature, a headache, sore, red eyes, swollen joints and joint and muscle pain, a rash and itching all over the body"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Zika virus
# Haemophilus influenzae type b (Hib): 21.00%
# Zika virus: 63.00%

# %%
random_symptoms = "lightheaded or dizzy, faint"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Heart block
# Heart block: 61.00%

# %%
random_symptoms = "being sick, diarrhoea and tummy pain, a skin rash, yellowing of the skin and eyes, blood in your poo, lots of bruises all over your body, bleeding from your ears, eyes, nose or mouth"
# random_symptoms = "elevated body temperature or subjective fever, chills, myalgia, and fatigue"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Ebola virus disease
# Ebola virus disease: 58.00%

# %%
random_symptoms = "severe diarrhea, vomiting, and dehydration"
# random_symptoms = "having lots of watery diarrhoea, feeling sick or being sick, tummy pain, dehydration"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Atrial fibrillation

# %%
random_symptoms = "a high temperature, a severe headache, pain behind your eyes, muscle and joint pain, feeling or being sick, swollen glands, a blotchy rash made up of flat or slightly raised spots – this can affect large areas of your body"
predict_disease(random_symptoms)
# Out:
# Predicted Condition: Dengue
# Appendicitis: 13.00%
# Dengue: 64.00%
# Hepatitis: 12.00%
